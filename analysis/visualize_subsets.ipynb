# %% [markdown]
# # Subset Visualization
#
# This notebook visualizes the selected subsets and compares them with baselines.
#
# ## TODO:
# - Display sample images from selected subsets
# - Show class distribution histograms
# - Compare GA-selected vs random vs baseline subsets

# %%
# TODO: Load selected subsets from results/
# TODO: Display sample images
# TODO: Plot class distributions
# TODO: Compare with baseline subsets
